# %%
#. How do you concatenate two strings in Python?
str1 = "Hello"
str2 = "World"

result = str1 + " " + str2
print(result)
# Out:
# Hello World

# %%
#What is the di erence between the + operator and the join() method for concatenating strings?
str1 = "Hello"
str2 = "World"

result = str1 + " " + str2
print(result)
# Out:
# Hello World

# %%
#How do you access individual characters in a string?
text = "Python"

print(text[0])  # first character
print(text[1])  # second character
print(text[5])  # sixth character
# Out:
# P
# y
# n

# %%
# What method is used to find the length of a string in Python?
text = "Hello, World!"
length = len(text)
print(length)
# Out:
# 13

# %%
#How can you convert a string to uppercase in Python?
text = "Hello, World!"
uppercase_text = text.upper()
print(uppercase_text)
# Out:
# HELLO, WORLD!

# %%
# How can you convert a string to lowercase in Python?
text = "Hello, World!"
lowercase_text = text.lower()
print(lowercase_text)
# Out:
# hello, world!

# %%
#What method is used to replace substrings within a string?
text = "I like Python. Python is fun."
new_text = text.replace("Python", "Java")
print(new_text)
# Out:
# I like Java. Java is fun.

# %%
#How can you split a string into a list of substrings based on a delimiter?
text = "Python is fun"
words = text.split()
print(words)
# Out:
# ['Python', 'is', 'fun']

# %%
#How do you check if a string starts with a particular substring?
text = "Hello, World!"
result = text.startswith("Hello")
print(result)
# Out:
# True

# %%
# How do you check if a string ends with a particular substring?
text = "Hello, World!"
result = text.endswith("World!")
print(result)
# Out:
# True

# %%
#How can you remove leading and trailing whitespace from a string?
text = "   Hello, World!   "
clean_text = text.strip()
print(clean_text)
# Out:
# Hello, World!

# %%
# What method is used to find the index of the first occurrence of a substring within a string?
text = "Python programming"
index = text.find("program")
print(index)
# Out:
# 7

# %%
#How can you count the number of occurrences of a substring within a string?
text = "Python is fun. Python is easy."
count = text.count("Python")
print(count)
# Out:
# 2

# %%
# How do you check if a string contains only alphabetic characters?
text = "Python"
print(text.isalpha())
# Out:
# True

# %%
#How do you check if a string contains only numeric characters?
text = "12345"
print(text.isdigit())
# Out:
# True

# %%
#How can you check if a string is a palindrome?
text = "racecar"

# Check if the string is equal to its reverse
if text == text[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Palindrome

# %%
#How can you reverse a string in Python?
text = "Python"
reversed_text = text[::-1]
print(reversed_text)
# Out:
# nohtyP

# %%
#How do you format a string with placeholders for variable values?
name = "Alice"
age = 25

formatted_text = f"My name is {name} and I am {age} years old."
print(formatted_text)
# Out:
# My name is Alice and I am 25 years old.

# %%
# How do you access a substring of a string using slicing?
text = "Python"
sub = text[0:4]  # from index 0 up to (but not including) 4
print(sub)
# Out:
# Pyth

# %%
# How can you remove specific characters from a string in Python?
text = "Hello, World!"
new_text = text.replace(",", "")  # remove comma
print(new_text)
# Out:
# Hello World!

# %%
# Offer Letter Generator

company_city =input("enter city name")
candidate_name =input("candidate name")
position =input("position name")
joining_date =input("date")
salary =input("salary")
hr_name =input("hr name")
hr_position =input("HR position")
email =input("e.mail")

offer_letter = f"""
{company_city}

Dear {candidate_name},

Subject: Offer of Employment for the position of {position}

We are delighted to extend this formal offer of employment to you for the position of {position} at our organization. Based on your qualifications and the skills you demonstrated during the recruitment process, we are confident that you will be a valuable addition to our team.

As discussed, your expected date of joining is {joining_date}. Your total compensation package will be {salary}, which includes all salary components as per the company’s policy. Further details regarding your compensation will be provided in your employment contract.

We expect you to bring your best efforts to help the company achieve its goals, and we are committed to supporting your professional growth during your time with us.

Please confirm your acceptance of this offer by sending an email to {email} at your earliest convenience. Should you have any queries regarding this offer, feel free to reach out to us.

We look forward to having you onboard and are excited about the great things we can accomplish together.

Sincerely,
{hr_name}
{hr_position}
"""

# Print the letter
print(offer_letter)

# Save the letter to a file
with open("offer_letter.txt", "w") as file:
    file.write(offer_letter)
# Out:
# enter city name noida
# candidate name Ritik thakur
# position name Data Analyst
# date 10/03/2026
# salary 40000
# hr name piyush kumar
# HR position hr manager
# e.mail rt840710@gmail.com
# noida
#
# Dear Ritik thakur,
#
# Subject: Offer of Employment for the position of Data Analyst
#
# We are delighted to extend this formal offer of employment to you for the position of Data Analyst at our organization. Based on your qualifications and the skills you demonstrated during the recruitment process, we are confident that you will be a valuable addition to our team.
#
# As discussed, your expected date of joining is 10/03/2026. Your total compensation package will be 40000, which includes all salary components as per the company’s policy. Further details regarding your compensation will be provided in your employment contract.
#
# We expect you to bring your best efforts to help the company achieve its goals, and we are committed to supporting your professional growth during your time with us.
#
# Please confirm your acceptance of this offer by sending an email to rt840710@gmail.com at your earliest convenience. Should you have any queries regarding this offer, feel free to reach out to us.
#
# We look forward to having you onboard and are excited about the great things we can accomplish together.
#
# Sincerely,
# piyush kumar
# hr manager

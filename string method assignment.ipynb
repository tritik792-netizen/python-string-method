# %%
string = "Ths is python class"

# %% [markdown]
# # string.capitalize()

# %%
string = "This is python class"
string.capitalize()
# Out:
# 'This is python class'

# %% [markdown]
# # string.casefold()

# %%
string.casefold()
# Out:
# 'this is python class'

# %% [markdown]
# # string.center()

# %%
string.center(10,'*')
# Out:
# 'This is python class'

# %% [markdown]
# # string.count()

# %%
string.count("Ths is python class")
# Out:
# 0

# %% [markdown]
# # string.encode()

# %%
string.encode()
# Out:
# b'This is python class'

# %% [markdown]
# # string.endswith()

# %%
print(string.endswith("Ths is "))
print(string.endswith("python class"))
# Out:
# False
# True

# %% [markdown]
# # string.expandtabs()

# %%
print(string.expandtabs(11))
# Out:
# This is python class

# %% [markdown]
# # string.find()

# %%
print(string.find("python"))
# Out:
# 8

# %% [markdown]
# # string.format()

# %%
print(string.format("Ths is python class"))
# Out:
# This is python class

# %% [markdown]
# # string.format_map()

# %%
string.format_map(string)
# Out:
# 'This is python class'

# %% [markdown]
# # string.index()

# %%
string.index("python")
# Out:
# 8

# %% [markdown]
# # string.isalnum()

# %%
string.isalnum()
# Out:
# False

# %% [markdown]
# # string.isalpha()

# %%
string.isalpha()
# Out:
# False

# %% [markdown]
# # string.isdecimal()

# %%
string.isdecimal()
# Out:
# False

# %% [markdown]
# # string.isascii()

# %%
string.isascii()
# Out:
# True

# %% [markdown]
# # string.isdigit()

# %%
string.isdigit()
# Out:
# False

# %% [markdown]
# # string.isidentifier()

# %%
string.isidentifier()
# Out:
# False

# %% [markdown]
# # string.islower()

# %%
string.islower()
# Out:
# False

# %% [markdown]
# # string.isnumeric()

# %%
string.isnumeric()
# Out:
# False

# %% [markdown]
# # string.isprintable()

# %%
string.isprintable()
# Out:
# True

# %% [markdown]
# # string.isspace()

# %%
string.isspace()
# Out:
# False

# %% [markdown]
# # string.istitle()

# %%
string.istitle()
# Out:
# False

# %% [markdown]
# # string.isupper()

# %%
string.isupper()
# Out:
# False

# %% [markdown]
# # string.join()

# %%
string.join("2")
# Out:
# '2'

# %% [markdown]
# # string.ljust()

# %%
print(string.ljust(5))
# Out:
# This is python class

# %% [markdown]
# # string.lower()

# %%
string.lower()
# Out:
# 'this is python class'

# %% [markdown]
# # string.lstrip()

# %%
string.lstrip()
# Out:
# 'This is python class'

# %% [markdown]
# # string.maketrans()

# %%
table = str.maketrans("ab", "12")
print(string.translate(table))
# Out:
# This is python cl1ss

# %% [markdown]
# # string.partition()

# %%
result = string.partition(" ")
print(result)
# Out:
# ('This', ' ', 'is python class')

# %% [markdown]
# # string.removeprefix()

# %%
print(string.removeprefix("python"))
# Out:
# Thsispythonclass

# %% [markdown]
# # string.removesuffix()

# %%
string = "This is python class"
string.removesuffix("python")
# Out:
# 'This is python class'

# %% [markdown]
# # string.replace()

# %%
string.replace("python","java")
# Out:
# 'This is java class'

# %% [markdown]
# # string.rfind()

# %%
string.rfind("python")
# Out:
# 8

# %% [markdown]
# # string.rindex()

# %%
string.rindex("python")
# Out:
# 8

# %% [markdown]
# # string.rjust()

# %%
print(string.rjust(10))
# Out:
# This is python class

# %% [markdown]
# # string.rpartition()

# %%
string.rpartition("/")
# Out:
# ('', '', 'This is python class')

# %% [markdown]
# # string.rsplit()

# %%
string.rsplit()
# Out:
# ['This', 'is', 'python', 'class']

# %% [markdown]
# # string.split()

# %%
string.split()
# Out:
# ['This', 'is', 'python', 'class']

# %% [markdown]
# # string.splitlines()

# %%
string.splitlines()
# Out:
# ['This is python class']

# %% [markdown]
# # string.startswith()

# %%
print(string.startswith("This is"))
print(string.startswith("Python class"))
# Out:
# True
# False

# %% [markdown]
# # string.strip()

# %%
string.strip()
# Out:
# 'This is python class'

# %% [markdown]
# # string.swapcase()

# %%
string.swapcase()
# Out:
# 'tHIS IS PYTHON CLASS'

# %% [markdown]
# # string.title()

# %%
string.title()
# Out:
# 'This Is Python Class'

# %% [markdown]
# # string.translate()

# %%
table = str.maketrans("abc", "123")
print(string.translate(table))
# Out:
# This is python 3l1ss

# %% [markdown]
# # string.upper()

# %%
string.upper()
# Out:
# 'THIS IS PYTHON CLASS'

# %% [markdown]
# # string.zfill()

# %%
num = "42"
print(num.zfill(5))
# Out:
# 00042

# %%
input_string = "python"

reversed_str = ""
for char in input_string:

    reversed_str = char + reversed_str
print(reversed_str)
# Out:
# nohtyp

# %% [markdown]
# ### def reverse_string(input_string: str) -> str:
#
#     if not isinstance(input_string,str):
#         raise TypeError("Input must be a string")
#     reversed_str = ""
#     for char in input_string:
#         reversed_str = char + reversed_str
#     return reversed_str
# if __name__ == "__main__":
#     try:
#          user_input = input("Enter your string to reverse : ")
#          result = reverse_string(user_input)
#          print(f"Reversed string :{result}")
#     except TypeError as e:
#         print(e)
#     except Exception as e:
#         print(e)

# %%
number_list = [1,2,3,4,5,6,7,8,9]

# %%
largest = number_list[0]
for num in number_list:
    if num>largest:
        largest = num
print(largest)
# Out:
# 9

# %%
def find_largest_number(number_list: list[float]) -> float:
    if not isinstance(number_list,list):
        raise TypeError("Inmput must be a list of number float or int")
    if not number_list:
        raise ValueError("List can not be empty")
    for num in number_list:
        if not isinstance(num,(int,float)):
            raise TypeError("All elements must e numeric")
    largest = number_list[0]
    for num in number_list:
        if num>largest:
            largest = num
    return largest
if __name__ == "__main__":
    try:
        user_input = input("Enter number in the list int or float only: ")
        number_list = [float(itrm) for itrm in user_input.split()]
        result = find_largest_number(number_list)
        print("Largest number in the list is : ",result)
    except (TypeError,ValueError) as erroe:
        print(error)
    except Exception as e:
        print(e)
# Out:
# Enter number in the list int or float only:  1 2 3 4 6 6 6
# Largest number in the list is :  6.0
